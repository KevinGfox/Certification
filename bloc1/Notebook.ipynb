# %% [markdown]
# > Project summary
# - Import libraries
# - 1: USE API TO FIND THE WEATHER FOR THE 35 CITIES (+7 DAYS)
# - 2: SCRAPPING BOOKING.com
# - 3: CREATE CLEAN DATAFRAME WITH SCRAP BOOKING HOTELS DATAFRAME AND WEATHER DATAFRAME
# - 4: Create S3 bucket | DATA LAKE
# - 5: ETL process to clean data
# - 6: Use RDS to use clean data | DATA WAREHOUSE
# - 7: Define TOP5 cities based on average temperature for today + 7 days
# - 8: Define TOP20 hotels based on the TOP5 cities
# - 9: GRAPHICS | MAPBOX

# %% [markdown]
# # Import libraries

# %%
import pandas as pd

import requests
import os
import logging

import scrapy
from scrapy.crawler import CrawlerProcess

import plotly.express as px
import plotly.io as pio

import boto3
from sqlalchemy import create_engine, text
from sqlalchemy.orm import sessionmaker

# %% [markdown]
# # 1: USE API TO FIND THE WEATHER FOR THE 35 CITIES (+7 DAYS)

# %%
# Define variable for the cities
cities = ["Mont Saint Michel","St Malo","Bayeux","Le Havre","Rouen","Paris","Amiens","Lille","Strasbourg","Chateau du Haut Koenigsbourg","Colmar","Eguisheim","Besancon","Dijon","Annecy","Grenoble","Lyon","Gorges du Verdon","Bormes les Mimosas","Cassis","Marseille","Aix en Provence","Avignon","Uzes","Nimes","Aigues Mortes","Saintes Maries de la mer","Collioure","Carcassonne","Ariege","Toulouse","Montauban","Biarritz","Bayonne","La Rochelle"]

# %%
# Define access key to the API
APIkey = 'SECRET'

# %%
# Define a list with lower city name & "+" between words
all_cities = [x.lower().replace(" ","+") for x in cities]

# %%
# Define iteration to get the the wheather for the 35 cities from GPS coordonates
weather_list= []
for cities in all_cities:
    r = requests.get("https://nominatim.openstreetmap.org/search?q={}&format=json".format(cities))
    lat = r.json()[0]['lat']
    lon = r.json()[0]['lon']
    city = cities.lower().replace("+","")
    for i in range(8):
        r = requests.get(f"https://api.openweathermap.org/data/2.5/onecall?lat={lat}&lon={lon}&exclude=hourly,minutely&appid={APIkey}")
        temp_day = r.json()['daily'][i]['temp']['day']
        wind_speed = r.json()['daily'][i]['wind_speed']
        main_weather = r.json()['daily'][i]['weather'][0]['main']
        day=i
        weather_list.append([city,temp_day,wind_speed,main_weather,day])

# %%
# Create a dataframe from the list
df_all_cities = pd.DataFrame(weather_list, columns=['city','tempavg','windspeed','weather','day'])

# %% [markdown]
# # 2: SCRAPPING BOOKING.com

# %%
# Define the spider to crawl pages and get the data needed
class bookingSpider(scrapy.Spider):
    # Define variables
    locs = ["MontSaintMichel","StMalo","Bayeux","LeHavre","Rouen","Paris","Amiens","Lille","Strasbourg","ChateauduHautKoenigsbourg","Colmar","Eguisheim","Besancon","Dijon","Annecy","Grenoble","Lyon","GorgesduVerdon","BormeslesMimosas","Cassis","Marseille","AixenProvence","Avignon","Uzes","Nimes","AiguesMortes","SaintesMariesdelamer","Collioure","Carcassonne","Ariege","Toulouse","Montauban","Biarritz","Bayonne","LaRochelle"]
    name = "booking"
    init_url = dict() # set a dictionary for the urls to follow
    start_urls = ["https://www.booking.com/"]

    # Method to enter the cities in searching destination
    def parse(self, response):
        for loc in self.locs:
            # returns a new FormRequest object with its form field values pre-populated with those found in the HTML <form> element contained in the given response.
            yield scrapy.FormRequest.from_response(response,
                                                   formdata = {'ss': loc},
                                                   callback = self.after_search,
                                                   cb_kwargs = {'location':loc, 'page_no':0}
                                                   )

    # Method to find name, url, score and description of the hotels
    def after_search(self, response, location, page_no):
        # Condition to crawl pages
        if page_no == 0:
            self.init_url[location] = response.url
        
        cities = response.css('div.a826ba81c4.fe821aea6c.fa2f36ad22.afd256fc79.d08f526e0d.ed11e24d01.da89aeb942')
        for city in cities:
            name = city.css('div.fcab3ed991.a23c043802::text').get()
            url = city.css('a.e13098a59f').attrib['href']
            score = city.css('div.b5cd09854e.d10a6220b4::text').get()
            desc = city.css('div.d8eab2cf7f::text').get()
            
            dic = {'location': location,
                    'name': name,
                    'url': url,
                    'score':score,
                    'description': desc
                  }
            # initiate method for the parse_hotel GPS cordonnates 
            try: 
                yield response.follow(url = url,
                                      callback = self.GPS, 
                                      cb_kwargs = {'dic': dic}
                                     ) 
            except:
                dic['lat'] = None
                dic['lon'] = None
                yield dic
         
        if page_no <= 1: 
            # Create variable next_page by the url and end string to give to follow function below
            next_page = self.init_url[location]+"&offset="+str(25*(page_no+1)) 
            # follow method return a request instance to follow a link, here it is the next_page variable who contain previous url with a page tag at the end
            yield response.follow(next_page,
                                  callback = self.after_search,
                                  cb_kwargs = {'location':location, 'page_no':page_no+1}
                                 ) 

    # method to find GPS coordonates and split them in two variables lat & Lon        
    def GPS(self, response, dic): 
        try: 
            gps = response.css('a.jq_tooltip.loc_block_link_underline_fix.bui-link.show_on_map_hp_link.show_map_hp_link').attrib['data-atlas-latlng']   
        except:
            dic['lat']=None
            dic['lon']=None
            yield dic
            return None
        try:
            gps = gps.split(',')
            dic['lat']=float(gps[0])
            dic['lon']=float(gps[1])
            yield dic
        except:
            print("No way to split")
            dic['lat']=None
            dic['lon']=None
            yield dic
            
# Define a filename
filename = "scrap_booking.json"

# Remove previous file if it allready exist
if filename in os.listdir('src/'):
        os.remove('src/' + filename)

# Define the settings for the crawler process
process = CrawlerProcess(settings = {
    # simulate browser
    'USER_AGENT': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:98.0) Gecko/20100101 Firefox/98.0', 
    # display regular errors
    'LOG_LEVEL': logging.ERROR,
    "FEEDS": {
        'src/' + filename : {"format": "json"},
    }
})

# Initiate crawler
process.crawl(bookingSpider)
process.start()

# %% [markdown]
# # 3: Create merged data from scrapping

# %%
# Create datafram from json hotels scrapping
df_hotels = pd.read_json('src/scrap_booking.json')

# %%
# Removing lines with nan values from score column
df_hotels = df_hotels[df_hotels.score.isna() == False]

# %%
# Keep the best hotels from each city
df_hotels = df_hotels[df_hotels.score > 8]

# %%
# Rename location column to city
df_hotels.rename({'location': 'city'}, axis=1, inplace=True)

# %%
# Lower city column
df_hotels.city = df_hotels.city.apply(lambda x: x.lower())

# %%
# Create mergde data from both dataframes
merged_data = df_hotels.merge(df_all_cities, how='left', on='city')

# %%
# Create CSV file from dataframe
merged_data.to_csv('Hotel-weather', encoding='utf-8', index=False)

# %% [markdown]
# # 4: Create S3 bucket | DATA LAKE

# %%
# Create instance session boto3
session = boto3.Session()

# %%
# Go to S3 aws 
s3 = session.resource("s3")

# %%
# Create s3 bucket 
bucket = s3.create_bucket(Bucket="booking-bucket-data", CreateBucketConfiguration={'LocationConstraint': 'eu-west-3'})

# %%
# Upload csv file to the bucket
bucket.put_object(Key="Hotel-weather.csv", Body = data)

# %%
# Download from s3 bucket
bucket.download_file('Hotel-weather.csv', 'Hotel-weather.csv')

# %% [markdown]
# # 5: ETL process to clean data

# %%
# Define dataframe from S3 csv
df=pd.read_csv('Hotel-weather.csv')

# %%
# Define Hotel dataframe from the previous
df_hotels = df[['city','name','url','score','description','lat','lon']].drop_duplicates(keep='first')

# %%
# Change temperature to degree Celcius
def degree(x):
    deg = x - 273.15
    return deg

# %%
# Create dataframe weather from first dataframe and apply degree function
df_weather = df[['city','lat','lon','tempavg','windspeed','weather','day']]
df_weather.tempavg = df_weather.tempavg.apply(degree)

# %% [markdown]
# # 6: Use RDS to use clean data | DATA WAREHOUSE

# %%
from sqlalchemy import create_engine, text
from sqlalchemy.orm import sessionmaker

# %%
# Define database connection variables
DBHOST = "database-booking-kg.c9wr39q76493.eu-west-3.rds.amazonaws.com"
DBUSER = "SECRET"
DBPASS = "SECRET"
DBNAME = "postgres"

# %%
# Connect to my postgresSQL database
engine = create_engine(f"postgresql+psycopg2://{DBUSER}:{DBPASS}@{DBHOST}/{DBNAME}", echo=True)

# %%
# Initialize a sessionmaker to talk to our database
Session = sessionmaker(bind = engine)
# Instanciate session 
session = Session()

# %%
# Transform the dataframes to SQL
df_weather.to_sql("df_weather_sql", engine)
df_hotels.to_sql("df_hotels_sql", engine)
# Out:
# 2022-07-15 09:32:48,431 INFO sqlalchemy.engine.Engine select version()
# 2022-07-15 09:32:48,432 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-07-15 09:32:48,440 INFO sqlalchemy.engine.Engine select current_schema()
# 2022-07-15 09:32:48,441 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-07-15 09:32:48,459 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2022-07-15 09:32:48,459 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-07-15 09:32:48,465 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-07-15 09:32:48,466 INFO sqlalchemy.engine.Engine [generated in 0.00049s] {'name': 'df_weather_sql'}
# 2022-07-15 09:32:48,488 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-15 09:32:48,488 INFO sqlalchemy.engine.Engine
# CREATE TABLE df_weather_sql (
# 	index BIGINT,
# 	city TEXT,
# 	lat FLOAT(53),
# 	lon FLOAT(53),
# 	tempavg FLOAT(53),
# 	windspeed FLOAT(53),
# 	weather TEXT,
# 	day BIGINT
# )
#
#
# 2022-07-15 09:32:48,489 INFO sqlalchemy.engine.Engine [no key 0.00063s] {}
# 2022-07-15 09:32:48,562 INFO sqlalchemy.engine.Engine CREATE INDEX ix_df_weather_sql_index ON df_weather_sql (index)
# 2022-07-15 09:32:48,562 INFO sqlalchemy.engine.Engine [no key 0.00064s] {}
# 2022-07-15 09:32:48,576 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-15 09:32:48,584 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-15 09:32:48,635 INFO sqlalchemy.engine.Engine INSERT INTO df_weather_sql (index, city, lat, lon, tempavg, windspeed, weather, day) VALUES (%(index)s, %(city)s, %(lat)s, %(lon)s, %(tempavg)s, %(windspeed)s, %(weather)s, %(day)s)
# 2022-07-15 09:32:48,635 INFO sqlalchemy.engine.Engine [generated in 0.04098s] ({'index': 0, 'city': 'bayeux', 'lat': 49.27981023, 'lon': -0.71067492, 'tempavg': 20.140000000000043, 'windspeed': 5.54, 'weather': 'Clouds', 'day': 0}, {'index': 1, 'city': 'bayeux', 'lat': 49.27981023, 'lon': -0.71067492, 'tempavg': 23.870000000000005, 'windspeed': 4.63, 'weather': 'Clear', 'day': 1}, {'index': 2, 'city': 'bayeux', 'lat': 49.27981023, 'lon': -0.71067492, 'tempavg': 21.900000000000034, 'windspeed': 6.07, 'weather': 'Clear', 'day': 2}, {'index': 3, 'city': 'bayeux', 'lat': 49.27981023, 'lon': -0.71067492, 'tempavg': 23.689999999999998, 'windspeed': 5.93, 'weather': 'Clear', 'day': 3}, {'index': 4, 'city': 'bayeux', 'lat': 49.27981023, 'lon': -0.71067492, 'tempavg': 26.600000000000023, 'windspeed': 6.54, 'weather': 'Clear', 'day': 4}, {'index': 5, 'city': 'bayeux', 'lat': 49.27981023, 'lon': -0.71067492, 'tempavg': 31.890000000000043, 'windspeed': 4.68, 'weather': 'Clouds', 'day': 5}, {'index': 6, 'city': 'bayeux', 'lat': 49.27981023, 'lon': -0.71067492, 'tempavg': 30.730000000000018, 'windspeed': 5.99, 'weather': 'Clouds', 'day': 6}, {'index': 7, 'city': 'bayeux', 'lat': 49.27981023, 'lon': -0.71067492, 'tempavg': 23.879999999999995, 'windspeed': 4.49, 'weather': 'Clouds', 'day': 7}  ... displaying 10 of 13744 total bound parameter sets ...  {'index': 13742, 'city': 'bormeslesmimosas', 'lat': 43.152872, 'lon': 6.342654, 'tempavg': 29.700000000000045, 'windspeed': 4.46, 'weather': 'Clear', 'day': 6}, {'index': 13743, 'city': 'bormeslesmimosas', 'lat': 43.152872, 'lon': 6.342654, 'tempavg': 30.260000000000048, 'windspeed': 5.37, 'weather': 'Clear', 'day': 7})
# 2022-07-15 09:32:49,388 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-15 09:32:49,395 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-07-15 09:32:49,396 INFO sqlalchemy.engine.Engine [cached since 0.9299s ago] {'name': 'df_hotels_sql'}
# 2022-07-15 09:32:49,403 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-15 09:32:49,404 INFO sqlalchemy.engine.Engine
# CREATE TABLE df_hotels_sql (
# 	index BIGINT,
# 	city TEXT,
# 	name TEXT,
# 	url TEXT,
# 	score FLOAT(53),
# 	description TEXT,
# 	lat FLOAT(53),
# 	lon FLOAT(53)
# )
#
#
# 2022-07-15 09:32:49,404 INFO sqlalchemy.engine.Engine [no key 0.00035s] {}
# 2022-07-15 09:32:49,424 INFO sqlalchemy.engine.Engine CREATE INDEX ix_df_hotels_sql_index ON df_hotels_sql (index)
# 2022-07-15 09:32:49,424 INFO sqlalchemy.engine.Engine [no key 0.00050s] {}
# 2022-07-15 09:32:49,431 INFO sqlalchemy.engine.Engine COMMIT
# 2022-07-15 09:32:49,438 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-07-15 09:32:49,446 INFO sqlalchemy.engine.Engine INSERT INTO df_hotels_sql (index, city, name, url, score, description, lat, lon) VALUES (%(index)s, %(city)s, %(name)s, %(url)s, %(score)s, %(description)s, %(lat)s, %(lon)s)
# 2022-07-15 09:32:49,448 INFO sqlalchemy.engine.Engine [generated in 0.00879s] ({'index': 0, 'city': 'bayeux', 'name': 'Hôtel Le Saint Patrice', 'url': 'https://www.booking.com/hotel/fr/saint-patrice.en-gb.html?label=gen173nr-1FCAEoggI46AdIM1gEaBWIAQGYAQm4ARjIAQ_YAQHoAQH4AQuIAgGoAgS4Aoqu9pIGwAIB0gIkMD ... (149 characters truncated) ... _rooms=1&group_children=0&req_children=0&hpos=25&hapos=25&sr_order=popularity&srpvid=06a07685260201ca&srepoch=1650300685&from=searchresults#hotelTmpl', 'score': 8.4, 'description': 'Set in Bayeux, within 400 metres of Cathedrale Notre Dame de Bayeux and 800 metres of Baron Gerard Museum, Hôtel Le Saint Patrice offers free WiFi throughout the property. ', 'lat': 49.27981023, 'lon': -0.71067492}, {'index': 8, 'city': 'bayeux', 'name': 'La Maison de Mathilde', 'url': 'https://www.booking.com/hotel/fr/la-maison-de-mathilde.en-gb.html?label=gen173nr-1FCAEoggI46AdIM1gEaBWIAQGYAQm4ARjIAQ_YAQHoAQH4AQuIAgGoAgS4Aoqu9pIGwA ... (157 characters truncated) ... _rooms=1&group_children=0&req_children=0&hpos=24&hapos=24&sr_order=popularity&srpvid=06a07685260201ca&srepoch=1650300685&from=searchresults#hotelTmpl', 'score': 9.0, 'description': 'La Maison de Mathilde is set in Bayeux, 100 metres from Baron Gerard Museum and 200 metres from Museum of the Bayeux Tapestry. ', 'lat': 49.27647468, 'lon': -0.70247008}, {'index': 16, 'city': 'lehavre', 'name': 'Hôtel Carmin', 'url': 'https://www.booking.com/hotel/fr/carmin.en-gb.html?label=gen173nr-1FCAEoggI46AdIM1gEaBWIAQGYAQm4ARjIAQ_YAQHoAQH4AQuIAgGoAgS4Aoqu9pIGwAIB0gIkMDVhZjBjM ... (156 characters truncated) ... _children=0&req_children=0&hpos=8&hapos=8&sr_order=popularity&srpvid=f80476862d3601ba&srepoch=1650300685&from_beach_sr=1&from=searchresults#hotelTmpl', 'score': 8.5, 'description': 'Hôtel Carmin is located in Le Havre town centre, 700m from the HAVRE beach It offers en suite rooms and free Wi-Fi. Rooms at the Carmin are equipped with a telephone and a flat-screen TV. ', 'lat': 49.49493852, 'lon': 0.10553956}, {'index': 24, 'city': 'lehavre', 'name': 'Best Western Plus Le Havre Centre Gare', 'url': 'https://www.booking.com/hotel/fr/hotelterminuslehavre.en-gb.html?label=gen173nr-1FCAEoggI46AdIM1gEaBWIAQGYAQm4ARjIAQ_YAQHoAQH4AQuIAgGoAgS4Aoqu9pIGwAI ... (201 characters truncated) ... =6&hapos=6&sr_order=popularity&srpvid=f80476862d3601ba&srepoch=1650300685&from_beach_sr=1&from_sustainable_property_sr=1&from=searchresults#hotelTmpl', 'score': 8.5, 'description': "Located in central Le Havre, Best Western Plus Le Havre Centre Gare is a 4 star design hotel offering free WiFi just 10 minutes' drive from the beach. ", 'lat': 49.49334357, 'lon': 0.12431771}, {'index': 32, 'city': 'eguisheim', 'name': 'La Légende des 2 Pierres', 'url': 'https://www.booking.com/hotel/fr/la-legende-des-2-pierres.en-gb.html?label=gen173nr-1FCAEoggI46AdIM1gEaBWIAQGYAQm4ARjIAQ_YAQHoAQH4AQuIAgGoAgS4Aoqu9pI ... (160 characters truncated) ... _rooms=1&group_children=0&req_children=0&hpos=17&hapos=17&sr_order=popularity&srpvid=79a276860f0901dc&srepoch=1650300686&from=searchresults#hotelTmpl', 'score': 9.2, 'description': 'Located in the quaint village of Eguisheim, La Légende des 2 Pierres offers a self-catering apartment with mountain views. Ski storage is provided in the apartment. ', 'lat': 48.04299853, 'lon': 7.30448939}, {'index': 40, 'city': 'chateauduhautkoenigsbourg', 'name': 'Logis Du Haut-Koenigsbourg', 'url': 'https://www.booking.com/hotel/fr/logis-du-haut-koenigsbourg.en-gb.html?label=gen173nr-1FCAEoggI46AdIM1gEaBWIAQGYAQm4ARjIAQ_YAQHoAQH4AQuIAgGoAgS4Aoqu9 ... (170 characters truncated) ... &group_children=0&req_children=0&hpos=4&hapos=4&sr_order=distance_from_search&srpvid=67717686c80c025c&srepoch=1650300686&from=searchresults#hotelTmpl', 'score': 9.1, 'description': 'Logis Du Haut-Koenigsbourg offers accommodation situated in Thannenkirch in the Alsace Region and is 49 km from Strasbourg. The property features views of the mountains and is 25 km from Colmar. ', 'lat': 48.24415784, 'lon ...
# 2022-07-15 09:32:50,036 INFO sqlalchemy.engine.Engine COMMIT

# %%
# Create a statement
# SQL base selection for the next data analysis team
Selection_weather = text("SELECT * FROM df_weather_sql")
df_weather = pd.read_sql(Selection_weather, engine)

Selection_hotels = text("SELECT * FROM df_hotels_sql")
df_hotels = pd.read_sql(Selection_hotels, engine)
# Out:
# 2022-07-15 09:33:00,332 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-07-15 09:33:00,332 INFO sqlalchemy.engine.Engine [cached since 11.87s ago] {'name': 'SELECT * FROM df_weather_sql'}
# 2022-07-15 09:33:00,342 INFO sqlalchemy.engine.Engine SELECT * FROM df_weather_sql
# 2022-07-15 09:33:00,342 INFO sqlalchemy.engine.Engine [generated in 0.00046s] {}
# 2022-07-15 09:33:00,498 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-07-15 09:33:00,498 INFO sqlalchemy.engine.Engine [cached since 12.03s ago] {'name': 'SELECT * FROM df_hotels_sql'}
# 2022-07-15 09:33:00,511 INFO sqlalchemy.engine.Engine SELECT * FROM df_hotels_sql
# 2022-07-15 09:33:00,511 INFO sqlalchemy.engine.Engine [generated in 0.00072s] {}

# %% [markdown]
# # 7: Define TOP5 cities based on average temperature for today + 7 days

# %%
# Create dataframe with descending value means from average temperature column
df_weather_mean = df_weather.groupby(by='city', as_index = False).mean().sort_values(by = 'tempavg',ascending = False)

# %%
# Create new dataframe with only five first rows
df_weather_top5 = df_weather_mean.head(5)

# %%
# Create list of city with higher average temperature for the 7 days
Top5_cities = df_weather_top5.city.tolist()

# %% [markdown]
# # 8: Define TOP20 hotels based on the TOP5 cities

# %%
# Create dataframe from the top5 list of best cities
df_hotels_best = df_hotels[df_hotels['city'].isin(Top5_cities)]

# %%
# Create dataframe from previous sorting values from city and score columns
df_hotels_best_score = df_hotels_best.sort_values(by = ['city','score'],ascending = False)

# %%
# Create grouped dataframe from previous by the city column
grouped_city_df = df_hotels_best_score.groupby('city')

# %%
# Create dataframe with only 20 first rows from preivou grouped dataframe
Top20_hotels = grouped_city_df.head(20)

# %% [markdown]
# # 9: GRAPHICS | MAPBOX

# %%
# Display weather map
fig = px.scatter_mapbox(df_weather.sort_values('day'),
                        title='Weather map',
                        lat = 'lat',
                        lon = 'lon',
                        color = 'tempavg',
                        color_continuous_scale = px.colors.diverging.balance,
                        size = 'windspeed',
                        size_max = 30,
                        hover_name = 'city',
                        animation_frame = 'day'
                        )
fig.update_layout(width = 1000,
                  height = 800,
                  title_x = 0.5, 
                  template = 'plotly_dark',
                  mapbox = {"style": "carto-darkmatter", "center": {"lon": 2, "lat" : 47}, "zoom": 4.8},
                  margin = {"l": 0, "r": 0, "b": 0, "t": 80},
                  )

fig.show()

# %%
# Display Top 20 hotels for the top 5 cities
fig = px.scatter_mapbox(Top20_hotels,
                        title = 'Best Hotels',
                        lat = 'lat',
                        lon = 'lon',
                        color = 'score',
                        size = 'score',
                        color_continuous_scale = px.colors.diverging.Tropic,
                        size_max = 20,
                        hover_name = 'name',
                        hover_data = {'description': True}
                        )
fig.update_layout(width = 1000,
                  height = 800,
                  title_x = 0.5, 
                  template='plotly_dark',
                  mapbox = {"style": "carto-darkmatter", "center": {"lon": 2.6, "lat" : 43.5}, "zoom": 7},
                  margin = {"l": 0, "r": 0, "b": 0, "t": 80},
                  )
fig.show()
